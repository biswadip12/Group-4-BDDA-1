# %%
#GROUP 4 
#015002 ANUKSHA JAIN
#015005 AYUSHI GUPTA
#015015 ANIKET NANDY
#015025 BISWADEEP DAS
#015045 SIDDHARTH GUPTA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
train=pd.read_csv(r"//content/train.csv.zip")

# %%
train.head()
# Out:
#    Id   Open Date        City  City Group Type  ...  P34  P35  P36  P37    revenue
# 0   0  07/17/1999    İstanbul  Big Cities   IL  ...    5    4    3    4  5653753.0
# 1   1  02/14/2008      Ankara  Big Cities   FC  ...    0    0    0    0  6923131.0
# 2   2  03/09/2013  Diyarbakır       Other   IL  ...    0    0    0    0  2055379.0
# 3   3  02/02/2012       Tokat       Other   IL  ...   18   12   12    6  2675511.0
# 4   4  05/09/2009   Gaziantep       Other   IL  ...    3    4    3    3  4316715.0
#
# [5 rows x 43 columns]

# %%
train.shape
# Out:
# (137, 43)

# %%
#Knowing general information about our file

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          137 non-null    int64
#  1   Open Date   137 non-null    object
#  2   City        137 non-null    object
#  3   City Group  137 non-null    object
#  4   Type        137 non-null    object
#  5   P1          137 non-null    int64
#  6   P2          137 non-null    float64
#  7   P3          137 non-null    float64
#  8   P4          137 non-null    float64
#  9   P5          137 non-null    int64
#  10  P6          137 non-null    int64
#  11  P7          137 non-null    int64
#  12  P8          137 non-null    int64
#  13  P9          137 non-null    int64
#  14  P10         137 non-null    int64
#  15  P11         137 non-null    int64
#  16  P12         137 non-null    int64
#  17  P13         137 non-null    float64
#  18  P14         137 non-null    int64
#  19  P15         137 non-null    int64
#  20  P16         137 non-null    int64
#  21  P17         137 non-null    int64
#  22  P18         137 non-null    int64
#  23  P19         137 non-null    int64
#  24  P20         137 non-null    int64
#  25  P21         137 non-null    int64
#  26  P22         137 non-null    int64
#  27  P23         137 non-null    int64
#  28  P24         137 non-null    int64
#  29  P25         137 non-null    int64
#  30  P26         137 non-null    float64
#  31  P27         137 non-null    float64
#  32  P28         137 non-null    float64
#  33  P29         137 non-null    float64
#  34  P30         137 non-null    int64
#  35  P31         137 non-null    int64
#  36  P32         137 non-null    int64
#  37  P33         137 non-null    int64
#  38  P34         137 non-null    int64
#  39  P35         137 non-null    int64
#  40  P36         137 non-null    int64
#  41  P37         137 non-null    int64
#  42  revenue     137 non-null    float64
# dtypes: float64(9), int64(30), object(4)
# memory usage: 46.1+ KB

# %%
#checking null values
train.isnull().sum()
# Out:
# Id            0
# Open Date     0
# City          0
# City Group    0
# Type          0
# P1            0
# P2            0
# P3            0
# P4            0
# P5            0
# P6            0
# P7            0
# P8            0
# P9            0
# P10           0
# P11           0
# P12           0
# P13           0
# P14           0
# P15           0
# P16           0
# P17           0
# P18           0
# P19           0
# P20           0
# P21           0
# P22           0
# P23           0
# P24           0
# P25           0
# P26           0
# P27           0
# P28           0
# P29           0
# P30           0
# P31           0
# P32           0
# P33           0
# P34           0
# P35           0
# P36           0
# P37           0
# revenue       0
# dtype: int64

# %%
#checking rows and columns 
train.shape
# Out:
# (137, 43)

# %%
#The ID column is irrelevant so we will drop them.
train=train.drop(['Id'],axis=1)
train
# Out:
#       Open Date        City  City Group Type  P1  ...  P34  P35  P36  P37    revenue
# 0    07/17/1999    İstanbul  Big Cities   IL   4  ...    5    4    3    4  5653753.0
# 1    02/14/2008      Ankara  Big Cities   FC   4  ...    0    0    0    0  6923131.0
# 2    03/09/2013  Diyarbakır       Other   IL   2  ...    0    0    0    0  2055379.0
# 3    02/02/2012       Tokat       Other   IL   6  ...   18   12   12    6  2675511.0
# 4    05/09/2009   Gaziantep       Other   IL   3  ...    3    4    3    3  4316715.0
# ..          ...         ...         ...  ...  ..  ...  ...  ...  ...  ...        ...
# 132  06/25/2008     Trabzon       Other   FC   2  ...    0    0    0    0  5787594.0
# 133  10/12/2006       İzmir  Big Cities   FC   4  ...    0    0    0    0  9262754.0
# 134  07/08/2006     Kayseri       Other   FC   3  ...    0    0    0    0  2544857.0
# 135  10/29/2010    İstanbul  Big Cities   FC   4  ...    0    0    0    0  7217634.0
# 136  09/01/2009    İstanbul  Big Cities   FC   4  ...    0    0    0    0  6363241.0
#
# [137 rows x 42 columns]

# %%
train['Open Date'] = pd.to_datetime(train['Open Date'])
train
# Out:
#      Open Date        City  City Group Type  P1  ...  P34  P35  P36  P37    revenue
# 0   1999-07-17    İstanbul  Big Cities   IL   4  ...    5    4    3    4  5653753.0
# 1   2008-02-14      Ankara  Big Cities   FC   4  ...    0    0    0    0  6923131.0
# 2   2013-03-09  Diyarbakır       Other   IL   2  ...    0    0    0    0  2055379.0
# 3   2012-02-02       Tokat       Other   IL   6  ...   18   12   12    6  2675511.0
# 4   2009-05-09   Gaziantep       Other   IL   3  ...    3    4    3    3  4316715.0
# ..         ...         ...         ...  ...  ..  ...  ...  ...  ...  ...        ...
# 132 2008-06-25     Trabzon       Other   FC   2  ...    0    0    0    0  5787594.0
# 133 2006-10-12       İzmir  Big Cities   FC   4  ...    0    0    0    0  9262754.0
# 134 2006-07-08     Kayseri       Other   FC   3  ...    0    0    0    0  2544857.0
# 135 2010-10-29    İstanbul  Big Cities   FC   4  ...    0    0    0    0  7217634.0
# 136 2009-09-01    İstanbul  Big Cities   FC   4  ...    0    0    0    0  6363241.0
#
# [137 rows x 42 columns]

# %%
#Extracting month and year 
train['month']=[x.month for x in train['Open Date']]
train['year']=[x.year for x in train['Open Date']]

# %%
#Dropping date column
train=train.drop(['Open Date'],axis=1)
train
# Out:
#            City  City Group Type  P1   P2  ...  P36  P37    revenue  month  year
# 0      İstanbul  Big Cities   IL   4  5.0  ...    3    4  5653753.0      7  1999
# 1        Ankara  Big Cities   FC   4  5.0  ...    0    0  6923131.0      2  2008
# 2    Diyarbakır       Other   IL   2  4.0  ...    0    0  2055379.0      3  2013
# 3         Tokat       Other   IL   6  4.5  ...   12    6  2675511.0      2  2012
# 4     Gaziantep       Other   IL   3  4.0  ...    3    3  4316715.0      5  2009
# ..          ...         ...  ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132     Trabzon       Other   FC   2  3.0  ...    0    0  5787594.0      6  2008
# 133       İzmir  Big Cities   FC   4  5.0  ...    0    0  9262754.0     10  2006
# 134     Kayseri       Other   FC   3  4.0  ...    0    0  2544857.0      7  2006
# 135    İstanbul  Big Cities   FC   4  5.0  ...    0    0  7217634.0     10  2010
# 136    İstanbul  Big Cities   FC   4  5.0  ...    0    0  6363241.0      9  2009
#
# [137 rows x 43 columns]

# %%
#knowing about the ocurences of month-for which month we have the maximum data
plt.figure(figsize=(20,8))
sns.countplot(train['month'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#occurence of various months in the dataset. 
#Most data for the last 5 months. The highest of them is from August and December.

# %%
plt.figure(figsize=(20,6))
sns.countplot(train['year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#occurence of various years in the dataset. 
#Most data for the restras which opened in 2008-13. The highest of them is from 2011.

# %%
#check the distribution and outliers
sns.distplot(a=train['revenue'], kde=True).set(xlabel='revenue', ylabel='P(revenue)')
#rightly skewed distribution with three outliers
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'P(revenue)'), Text(0.5, 0, 'revenue')]

# %%
train[train['revenue'] > 10000000 ]
# Out:
#         City  City Group Type  P1   P2  ...  P36  P37     revenue  month  year
# 16  İstanbul  Big Cities   FC   3  5.0  ...    0    0  19696939.0      1  2000
# 75  İstanbul  Big Cities   FC   5  5.0  ...    0    0  16549064.0     10  2005
# 99  İstanbul  Big Cities   IL   4  5.0  ...    5    3  13575224.0     12  1999
#
# [3 rows x 43 columns]

# %%
# Drop outliers
train = train[train['revenue'] < 10000000 ]
train.reset_index(drop=True).head()
# Out:
#          City  City Group Type  P1   P2  ...  P36  P37    revenue  month  year
# 0    İstanbul  Big Cities   IL   4  5.0  ...    3    4  5653753.0      7  1999
# 1      Ankara  Big Cities   FC   4  5.0  ...    0    0  6923131.0      2  2008
# 2  Diyarbakır       Other   IL   2  4.0  ...    0    0  2055379.0      3  2013
# 3       Tokat       Other   IL   6  4.5  ...   12    6  2675511.0      2  2012
# 4   Gaziantep       Other   IL   3  4.0  ...    3    3  4316715.0      5  2009
#
# [5 rows x 43 columns]

# %%
#which month has highest revenue
train.groupby('month')['revenue'].mean()
# Out:
# month
# 1     4.521243e+06
# 2     4.189109e+06
# 3     3.969557e+06
# 4     4.726097e+06
# 5     3.657800e+06
# 6     3.776214e+06
# 7     3.458596e+06
# 8     3.883020e+06
# 9     5.390856e+06
# 10    4.428821e+06
# 11    4.721400e+06
# 12    3.720047e+06
# Name: revenue, dtype: float64

# %%
#september had most revenue.

# %%
#visulaizing the samee
sns.barplot('month','revenue',data=train)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#which year has highest revenue
train.groupby('year')['revenue'].mean()
# Out:
# year
# 1996    3.903884e+06
# 1997    4.286645e+06
# 1998    4.251905e+06
# 1999    5.246965e+06
# 2000    7.495092e+06
# 2002    4.991022e+06
# 2004    3.482435e+06
# 2005    3.298470e+06
# 2006    4.203972e+06
# 2007    5.079333e+06
# 2008    4.876962e+06
# 2009    4.652457e+06
# 2010    4.383878e+06
# 2011    4.147879e+06
# 2012    3.837859e+06
# 2013    2.532287e+06
# 2014    2.464944e+06
# Name: revenue, dtype: float64

# %%
#highest revenue in year 2000.

# %%
#Exploring categorical variables

# %%
train['Type'].value_counts()
# Out:
# FC    74
# IL    59
# DT     1
# Name: Type, dtype: int64

# %%
types={'FC':0,'IL':1,'DT':2}
train['Type'] = train['Type'].map(types)
train
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            City  City Group  Type  P1   P2  ...  P36  P37    revenue  month  year
# 0      İstanbul  Big Cities     1   4  5.0  ...    3    4  5653753.0      7  1999
# 1        Ankara  Big Cities     0   4  5.0  ...    0    0  6923131.0      2  2008
# 2    Diyarbakır       Other     1   2  4.0  ...    0    0  2055379.0      3  2013
# 3         Tokat       Other     1   6  4.5  ...   12    6  2675511.0      2  2012
# 4     Gaziantep       Other     1   3  4.0  ...    3    3  4316715.0      5  2009
# ..          ...         ...   ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132     Trabzon       Other     0   2  3.0  ...    0    0  5787594.0      6  2008
# 133       İzmir  Big Cities     0   4  5.0  ...    0    0  9262754.0     10  2006
# 134     Kayseri       Other     0   3  4.0  ...    0    0  2544857.0      7  2006
# 135    İstanbul  Big Cities     0   4  5.0  ...    0    0  7217634.0     10  2010
# 136    İstanbul  Big Cities     0   4  5.0  ...    0    0  6363241.0      9  2009
#
# [134 rows x 43 columns]

# %%
#barplot for various type of restrauants with their revenue
sns.barplot(x='Type', y='revenue', data=train )

# %%
train['City Group'].value_counts()
# Out:
# Big Cities    75
# Other         59
# Name: City Group, dtype: int64

# %%
cities={'Big Cities':0,'Other':1}
train['City Group'] = train['City Group'].map(cities)
train
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            City  City Group  Type  P1   P2  ...  P36  P37    revenue  month  year
# 0      İstanbul           0     1   4  5.0  ...    3    4  5653753.0      7  1999
# 1        Ankara           0     0   4  5.0  ...    0    0  6923131.0      2  2008
# 2    Diyarbakır           1     1   2  4.0  ...    0    0  2055379.0      3  2013
# 3         Tokat           1     1   6  4.5  ...   12    6  2675511.0      2  2012
# 4     Gaziantep           1     1   3  4.0  ...    3    3  4316715.0      5  2009
# ..          ...         ...   ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132     Trabzon           1     0   2  3.0  ...    0    0  5787594.0      6  2008
# 133       İzmir           0     0   4  5.0  ...    0    0  9262754.0     10  2006
# 134     Kayseri           1     0   3  4.0  ...    0    0  2544857.0      7  2006
# 135    İstanbul           0     0   4  5.0  ...    0    0  7217634.0     10  2010
# 136    İstanbul           0     0   4  5.0  ...    0    0  6363241.0      9  2009
#
# [134 rows x 43 columns]

# %%
#barplot for city groups with their revenue

# %%
sns.barplot(x='City Group', y='revenue', data=train )

# %%
#Revenue of every city
#Edirne highest revenue

# %%
train.groupby('City')['revenue'].mean()
# Out:
# City
# Adana             4.894944e+06
# Afyonkarahisar    4.952497e+06
# Amasya            2.954086e+06
# Ankara            3.275406e+06
# Antalya           3.481448e+06
# Aydın             3.429798e+06
# Balıkesir         4.758476e+06
# Bolu              4.263629e+06
# Bursa             4.092295e+06
# Denizli           2.344689e+06
# Diyarbakır        3.735351e+06
# Edirne            5.444227e+06
# Elazığ            5.525735e+06
# Eskişehir         3.957953e+06
# Gaziantep         4.316715e+06
# Isparta           4.015749e+06
# Karabük           3.807496e+06
# Kastamonu         3.273041e+06
# Kayseri           4.567576e+06
# Kocaeli           3.745135e+06
# Konya             2.667256e+06
# Kütahya           2.993069e+06
# Kırklareli        1.619683e+06
# Muğla             4.111129e+06
# Osmaniye          3.376145e+06
# Sakarya           3.328853e+06
# Samsun            3.247870e+06
# Tekirdağ          3.312471e+06
# Tokat             2.675511e+06
# Trabzon           5.284100e+06
# Uşak              1.763231e+06
# İstanbul          4.873816e+06
# İzmir             5.287571e+06
# Şanlıurfa         3.261924e+06
# Name: revenue, dtype: float64

# %%
a=train['City'].value_counts()

# %%
b=a.index

# %%
c={}
for i,j in enumerate(b):
  c.update({j:i})
  print(c)
# Out:
# {'İstanbul': 0}
# {'İstanbul': 0, 'Ankara': 1}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26, 'Kastamonu': 27}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26, 'Kastamonu': 27, 'Balıkesir': 28}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26, 'Kastamonu': 27, 'Balıkesir': 28, 'Kırklareli': 29}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26, 'Kastamonu': 27, 'Balıkesir': 28, 'Kırklareli': 29, 'Edirne': 30}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26, 'Kastamonu': 27, 'Balıkesir': 28, 'Kırklareli': 29, 'Edirne': 30, 'Osmaniye': 31}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26, 'Kastamonu': 27, 'Balıkesir': 28, 'Kırklareli': 29, 'Edirne': 30, 'Osmaniye': 31, 'Kütahya': 32}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Bursa': 3, 'Samsun': 4, 'Antalya': 5, 'Sakarya': 6, 'Diyarbakır': 7, 'Adana': 8, 'Eskişehir': 9, 'Tekirdağ': 10, 'Kayseri': 11, 'Muğla': 12, 'Konya': 13, 'Aydın': 14, 'Trabzon': 15, 'Isparta': 16, 'Bolu': 17, 'Kocaeli': 18, 'Afyonkarahisar': 19, 'Elazığ': 20, 'Tokat': 21, 'Gaziantep': 22, 'Karabük': 23, 'Uşak': 24, 'Amasya': 25, 'Denizli': 26, 'Kastamonu': 27, 'Balıkesir': 28, 'Kırklareli': 29, 'Edirne': 30, 'Osmaniye': 31, 'Kütahya': 32, 'Şanlıurfa': 33}

# %%
train['City'] = train['City'].map(c)
train
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      City  City Group  Type  P1   P2  ...  P36  P37    revenue  month  year
# 0       0           0     1   4  5.0  ...    3    4  5653753.0      7  1999
# 1       1           0     0   4  5.0  ...    0    0  6923131.0      2  2008
# 2       7           1     1   2  4.0  ...    0    0  2055379.0      3  2013
# 3      21           1     1   6  4.5  ...   12    6  2675511.0      2  2012
# 4      22           1     1   3  4.0  ...    3    3  4316715.0      5  2009
# ..    ...         ...   ...  ..  ...  ...  ...  ...        ...    ...   ...
# 132    15           1     0   2  3.0  ...    0    0  5787594.0      6  2008
# 133     2           0     0   4  5.0  ...    0    0  9262754.0     10  2006
# 134    11           1     0   3  4.0  ...    0    0  2544857.0      7  2006
# 135     0           0     0   4  5.0  ...    0    0  7217634.0     10  2010
# 136     0           0     0   4  5.0  ...    0    0  6363241.0      9  2009
#
# [134 rows x 43 columns]

# %%
#co-relation matrix

# %%
corr_m=train.corr()

# %%
corr_m
# Out:
#                 City  City Group      Type  ...   revenue     month      year
# City        1.000000    0.727653 -0.046613  ... -0.182373  0.044700  0.212101
# City Group  0.727653    1.000000 -0.142432  ... -0.211989  0.035446  0.148095
# Type       -0.046613   -0.142432  1.000000  ... -0.086699 -0.064590 -0.102868
# P1         -0.183398   -0.261099  0.154457  ...  0.106975 -0.001502 -0.091001
# P2         -0.375715   -0.417732  0.113421  ...  0.217491 -0.070989 -0.161109
# P3         -0.036569   -0.089034  0.065811  ...  0.011755  0.034556 -0.028092
# P4         -0.047352   -0.176806  0.088882  ...  0.057928  0.051029  0.011922
# P5          0.164278    0.013845  0.108837  ...  0.002373 -0.008815  0.115942
# P6         -0.344831   -0.412403  0.166424  ...  0.125315 -0.049115 -0.175689
# P7         -0.100475   -0.198472  0.129602  ...  0.102491 -0.018747 -0.001588
# P8         -0.054565   -0.089085  0.114548  ...  0.001171  0.048601  0.011298
# P9          0.029584   -0.030556  0.152873  ...  0.013561  0.008217  0.055253
# P10         0.057634   -0.014816  0.150725  ...  0.018277  0.067075  0.046786
# P11         0.002738   -0.110723  0.071766  ...  0.049328 -0.067609 -0.084392
# P12         0.060591    0.009217  0.101636  ...  0.026608  0.022828  0.082490
# P13         0.087327    0.019471  0.142905  ...  0.008513  0.120176  0.089822
# P14        -0.049134   -0.133501  0.512171  ...  0.018282  0.027436 -0.194823
# P15        -0.047636   -0.128648  0.595392  ...  0.009322  0.011200 -0.151193
# P16        -0.051856   -0.145102  0.564051  ... -0.025185  0.000188 -0.098517
# P17        -0.092580   -0.181636  0.517945  ...  0.081541  0.024961 -0.208686
# P18        -0.031975   -0.136039  0.595120  ... -0.018292 -0.019541 -0.091921
# P19         0.064868   -0.058781  0.168103  ...  0.083804  0.049458 -0.041409
# P20        -0.105912   -0.165595  0.229007  ...  0.018973 -0.033972 -0.054842
# P21         0.033212   -0.037549  0.217370  ...  0.061999  0.040881 -0.093379
# P22        -0.309758   -0.252583  0.111316  ...  0.046387 -0.023063 -0.178915
# P23         0.043326   -0.012654  0.203951  ...  0.114357  0.094282 -0.044638
# P24        -0.181924   -0.239693  0.581777  ...  0.028426 -0.000178 -0.141888
# P25        -0.140782   -0.212058  0.575000  ...  0.049852 -0.029023 -0.215710
# P26        -0.167829   -0.230715  0.569586  ...  0.001369 -0.018407 -0.185920
# P27        -0.132421   -0.189481  0.553313  ...  0.046918 -0.010625 -0.143458
# P28        -0.228344   -0.296379  0.084816  ...  0.190908  0.032097 -0.122720
# P29         0.041764    0.010997  0.086448  ...  0.022115 -0.049651  0.000973
# P30        -0.029236   -0.128248  0.512715  ... -0.055073 -0.005873 -0.086768
# P31        -0.123456   -0.208894  0.567166  ... -0.028761 -0.112841 -0.103253
# P32        -0.085591   -0.176055  0.499070  ... -0.050743 -0.043766 -0.109814
# P33        -0.017756   -0.112986  0.665372  ...  0.010659 -0.031997 -0.135228
# P34        -0.027783   -0.121480  0.493669  ... -0.068246  0.016613 -0.091608
# P35        -0.023202   -0.131852  0.607474  ... -0.038330  0.051832 -0.051479
# P36        -0.038069   -0.140891  0.543897  ... -0.038126  0.000330 -0.106275
# P37        -0.010565   -0.092677  0.598853  ...  0.003478 -0.057248 -0.174345
# revenue    -0.182373   -0.211989 -0.086699  ...  1.000000  0.018076 -0.202740
# month       0.044700    0.035446 -0.064590  ...  0.018076  1.000000 -0.045583
# year        0.212101    0.148095 -0.102868  ... -0.202740 -0.045583  1.000000
#
# [43 rows x 43 columns]

# %%
corr_m['revenue'].sort_values(ascending=False).head(10)
#none shows strong postive correlation
# Out:
# revenue    1.000000
# P2         0.217491
# P28        0.190908
# P6         0.125315
# P23        0.114357
# P1         0.106975
# P7         0.102491
# P19        0.083804
# P17        0.081541
# P21        0.061999
# Name: revenue, dtype: float64

# %%
corr_m['revenue'].sort_values(ascending=False).tail(10)
#none shows strong negative correlation
# Out:
# P31          -0.028761
# P36          -0.038126
# P35          -0.038330
# P32          -0.050743
# P30          -0.055073
# P34          -0.068246
# Type         -0.086699
# City         -0.182373
# year         -0.202740
# City Group   -0.211989
# Name: revenue, dtype: float64

# %%
sns.set_theme()
fig, ax = plt.subplots(figsize=(45,30)) 
correlation_matrix = train.corr()
sns.heatmap(correlation_matrix,annot=True,linewidths=.5,ax=ax)

# %%
train.head()
# Out:
#    City  City Group  Type  P1   P2   P3  ...  P35  P36  P37    revenue  month  year
# 0     0           0     1   4  5.0  4.0  ...    4    3    4  5653753.0      7  1999
# 1     1           0     0   4  5.0  4.0  ...    0    0    0  6923131.0      2  2008
# 2     7           1     1   2  4.0  2.0  ...    0    0    0  2055379.0      3  2013
# 3    21           1     1   6  4.5  6.0  ...   12   12    6  2675511.0      2  2012
# 4    22           1     1   3  4.0  3.0  ...    4    3    3  4316715.0      5  2009
#
# [5 rows x 43 columns]

# %%
# splitting training and testing data
from sklearn.model_selection import train_test_split
x=train.drop('revenue',axis=1)
y=train['revenue']
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (93, 42)
# (93,)
# (41, 42)
# (41,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
dtr = DecisionTreeRegressor() #create the object of the model
dtr=dtr.fit(X_train,y_train)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
pred = dtr.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the DT regressor is: "+str(s))
print("The MsE with the DT regressor is: "+str(s1))
print("The R2_Score with the DT regressor is: "+str(s2))
# Out:
# The MAE with the DT regressor is: 1962041.975609756
# The MsE with the DT regressor is: 6880599603275.536
# The R2_Score with the DT regressor is: -1.4914359894159666

# %%
knn=KNeighborsRegressor()
knn=knn.fit(X_train,y_train)

# %%
pred = knn.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the KNN regressor is: "+str(s))
print("The MsE with the KNN regressor is: "+str(s1))
print("The R2_Score with the KNN regressor is: "+str(s2))
# Out:
# The MAE with the KNN regressor is: 1437306.3804878048
# The MsE with the KNN regressor is: 3016995207262.033
# The R2_Score with the KNN regressor is: -0.09244119301605358

# %%
r = RandomForestRegressor() #create the object of the model
r=r.fit(X_train,y_train)

# %%
pred = r.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the RF regressor is: "+str(s))
print("The MsE with the RF regressor is: "+str(s1))
print("The R2_Score with the RF regressor is: "+str(s2))
# Out:
# The MAE with the RF regressor is: 991171.7036585364
# The MsE with the RF regressor is: 1919363101954.0808
# The R2_Score with the RF regressor is: 0.305006745823578

# %%
#hypertuning to find best parameters

# %%
parameters = {'max_depth':  list(range(6, 30, 10)),
              'max_leaf_nodes': list(range(50, 500, 100)),
              'n_estimators': list(range(50, 1001, 150))}

parameters1 = {'max_depth':  [6],
              'max_leaf_nodes': [250],
              'n_estimators': [100]}
from sklearn.model_selection import GridSearchCV

gsearch = GridSearchCV(estimator=RandomForestRegressor(),
                       param_grid = parameters, 
                       scoring='neg_mean_squared_error',
                       n_jobs=4,cv=5,verbose=7)

gsearch.fit(x, y)
# Out:
# Fitting 5 folds for each of 105 candidates, totalling 525 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=4)]: Done 384 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=4)]: Done 504 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=4)]: Done 525 out of 525 | elapsed:  7.2min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=4,
#              param_grid={'max_depth': [6, 16, 26],
#                          'max_leaf_nodes': [50, 150, 250, 350, 450],
#                          'n_estimators': [50, 200, 350, 500, 650, 800, 950]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=7)

# %%
print(gsearch.best_params_.get('n_estimators'))
print(gsearch.best_params_.get('max_leaf_nodes'))
print(gsearch.best_params_.get('max_depth'))
# Out:
# 50
# 50
# 6

# %%
final_model = RandomForestRegressor(
                         max_depth = gsearch.best_params_.get('max_depth'),
                           max_leaf_nodes = gsearch.best_params_.get('max_leaf_nodes'),
    n_estimators = gsearch.best_params_.get('n_estimators'),random_state=1, n_jobs=4)
final_model.fit(x, y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=50,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=4, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False)
